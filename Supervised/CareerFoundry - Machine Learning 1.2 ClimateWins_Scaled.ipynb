# %% [markdown]
# This Script contains the following steps:
#
# 1. Importing data and libraries
# 2. Cleaning Data
# 3. Scaling

# %% [markdown]
# # 1. Importing data and libriaries

# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
# Defining the path
path = 'C:/Users/andyc/Machine Learning - ClimateWins'

# %%
#importing the Climatewins data set
ClimateWins = pd.read_csv(os.path.join(path, 'Data Sets', 'Dataset-weather-prediction-dataset-processed.csv'), index_col = False)

# %%
# Checking the first 5 rows of the ClimateWins data set
ClimateWins.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
# Reset index
# Renaming the index column to id
ClimateWins.reset_index(inplace=True)
ClimateWins.rename(columns={'index':'id'}, inplace=True)
ClimateWins.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
# Checking ClimateWins' info
ClimateWins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 171 entries, id to VALENTIA_temp_max
# dtypes: float64(145), int64(26)
# memory usage: 29.9 MB

# %% [markdown]
# # 2. Scaling

# %%
# Checking rows and columns
ClimateWins.shape
# Out:
# (22950, 171)

# %%
# Checking for missing values
ClimateWins.isnull().sum()
# Out:
# id                     0
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 171, dtype: int64

# %%
# eliminate those records that have NaN values
ClimateWins.dropna(inplace=True)

# %%
# Checking rows and columns after dropping missing values
ClimateWins.shape
# Out:
# (22950, 171)

# %% [markdown]
# No missing values are present in the data set.

# %%
# Checking for duplicates
ClimateWins_dupes = ClimateWins[ClimateWins.duplicated]

# %%
ClimateWins_dupes
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# No duplicates are present in the data set.

# %% [markdown]
# # 3. Scaling

# %%
# create scaler object using StandardScaler from sklearn.preprocessing
scaler = StandardScaler()

# %%
# create a new dataframe with scaled data

ClimateWins_scaled = pd.DataFrame(scaler.fit_transform(ClimateWins), columns=ClimateWins.columns)
ClimateWins_scaled.head()
# Out:
#          id      DATE     MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# 0 -1.731975 -1.707663 -1.599964           0.660514          -0.02793
# 1 -1.731824 -1.707657 -1.599964           0.244897          -0.02793
# 2 -1.731673 -1.707652 -1.599964           1.076130          -0.02793
# 3 -1.731523 -1.707646 -1.599964          -1.001953          -0.02793
# 4 -1.731372 -1.707641 -1.599964           0.244897          -0.02793
#
#    BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# 0        0.826097       -0.001949               -1.101066
# 1        0.735760       -0.001949               -1.058108
# 2        1.277781       -0.001949               -1.251420
# 3        1.458455       -0.001949               -0.821838
# 4        1.729466       -0.001949               -0.746661
#
#    BASEL_precipitation  BASEL_snow_depth  ...  VALENTIA_cloud_cover  \
# 0            -0.265148         -0.179228  ...             -0.443701
# ...

# %%
# Overwriting the 'date' column in the scaled dataframe with the original 'date' column in our ClimateWins dataframe
ClimateWins_scaled['DATE'] = ClimateWins['DATE']

# %%
ClimateWins_scaled.head()
# Out:
#          id      DATE     MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# 0 -1.731975  19600101 -1.599964           0.660514          -0.02793
# 1 -1.731824  19600102 -1.599964           0.244897          -0.02793
# 2 -1.731673  19600103 -1.599964           1.076130          -0.02793
# 3 -1.731523  19600104 -1.599964          -1.001953          -0.02793
# 4 -1.731372  19600105 -1.599964           0.244897          -0.02793
#
#    BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# 0        0.826097       -0.001949               -1.101066
# 1        0.735760       -0.001949               -1.058108
# 2        1.277781       -0.001949               -1.251420
# 3        1.458455       -0.001949               -0.821838
# 4        1.729466       -0.001949               -0.746661
#
#    BASEL_precipitation  BASEL_snow_depth  ...  VALENTIA_cloud_cover  \
# 0            -0.265148         -0.179228  ...             -0.443701
# ...

# %%
# Comparing the original data and the scaled data
ClimateWins.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
# exporting dataframe as pickle file
ClimateWins_scaled.to_csv(os.path.join(path, 'ClimateWins_scaled.csv'))
